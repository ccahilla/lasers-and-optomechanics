# %% [markdown]
# ---
# title: Pound-Drever-Hall Laser Frequency Locking
# date: 2025-03-18
# authors:
#   - name: Craig Cahillane
#     orcid: 0000-0002-3888-314X
#     affiliations:
#       - Syracuse University
# numbering:
#   heading_1: true
#   heading_2: true
#   heading_3: true
# ---

# %% [markdown]
# In the previous class, we discussed dither locking and explored it's capabilty to provide a local oscillator for detecting an
