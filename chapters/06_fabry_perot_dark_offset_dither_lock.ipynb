# %% [markdown]
# ---
# title: Fabry Perot Dark Offset and Dither Locking
# date: 2025-03-16
# authors:
#   - name: Craig Cahillane
#     orcid: 0000-0002-3888-314X
#     affiliations:
#       - Syracuse University
# numbering:
#   heading_1: true
#   heading_2: true
#   heading_3: true
# ---

# %% [markdown]
# In previous lessons,
# we have built up our repetoire of mathematical machinery to understand interferometry.
#
# For today's lesson, we will use our skills to investigate holding lock in a Fabry-P\'erot interferometer by introducing a end-mirror modulation.
#
# Follow this link to get the in-class tutorial
# [](https://ccahilla.github.io/lasers-and-optomechanics/build/01_fabry_perot_dark_-a98baed6deffe26bf31ab9cce3372929.pdf)

# %% [markdown]
# ![Screenshot 2026-03-15 at 6.21.46 PM.png](attachment:ae6810f1-7d02-4ac1-bf64-d1cb21ba094b.png)
