# %% [markdown]
# ---
# title: Coupled Cavities
# date: 2025-03-23
# authors:
#   - name: Craig Cahillane
#     orcid: 0000-0002-3888-314X
#     affiliations:
#       - Syracuse University
# numbering:
#   heading_1: true
#   heading_2: true
#   heading_3: true
# ---

# %% [markdown]
# ## Link to Coupled Cavity Tutorials and Solutions
#
# We'll have a Basics (Part 1) tutorial,\
# and a Sensing Matrix (Part 2) tutorial.
#
# [In-class Tutorials hosted here](https://ccahilla.github.io/lasers-and-optomechanics/tutorials/)

# %% [markdown]
# ![Screenshot 2026-03-21 at 7.37.29 PM.png](attachment:7e0e2449-0ecd-45e3-8fab-84d94756de3e.png)
